# %% [markdown]
# <a href="https://colab.research.google.com/github/joaovvgoncalves22/Prova1-/blob/main/Tanque_de_mistura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from dataclasses import dataclass

@dataclass
class Corrente:
  """
  vazão: vazão da corrente em kg/h
  Fração: fração massica em kg/h
  """
  vazão: float
  fração: float

# %%
print(Corrente.__doc__)
# Out:
#   vazão: vazão da corrente em kg/h
#   Fração: fração massica em kg/h

# %%
def misturador(c1: Corrente, c2: Corrente):
"""
  Calcule a vazão e a fração da mistura de  correntes
  E
  """


  #Primeira Corrente
  Fa = c1.vazão
  xa =  c1.fração

  #Segunda Corrente
  Fb = c2.vazão
  xb =  c2.fração

  #Vazão Total
  F = Fa + Fb

  x =(Fa*xa + Fb*xb)/(F)


  return F, x
